# %%
import pandas as pd

# %%
with open("data/emotion-words.txt") as f:
    words = [w.lower().strip() for w in f.readlines()]

# %%
for w in words:
    if w not in wordset:
        print(w)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-f5824b2d7a36> in <module>
# ----> 1 for w in words:
#       2     if w not in wordset:
#       3         print(w)
#
# TypeError: 'WordListCorpusReader' object is not iterable

# %%
from nltk.corpus import words

# %%
wordset = set(words.words())

# %%
set(wordlist)
# Out:
# {'epurate',
#  'palmanesthesia',
#  'cheesery',
#  'lanciform',
#  'almemar',
#  'progypsy',
#  'achloropsia',
#  'subarch',
#  'retaliation',
#  'allicient',
#  'muzhik',
#  'mannerable',
#  'unominous',
#  'weedable',
#  'advisorily',
#  'Winnipesaukee',
#  'isobront',
#  'archer',
#  'hypercryalgesia',
#  'alone',
#  'autodynamic',
#  'umpireship',
#  'hexogen',
#  'homocentrical',
#  'fitch',
#  'uncabined',
#  'biennially',
#  'autarky',
#  'banns',
#  'enantiosis',
#  'minionism',
#  'acacatechin',
#  'calices',
#  'Ctenocephalus',
#  'cresoxy',
#  'unmarginal',
#  'Caunos',
#  'cousiny',
#  'nonadjournment',
#  'surgeproof',
#  'Haimavati',
#  'condistillation',
#  'floaty',
#  'calligraphist',
#  'shaddock',
#  'epigrammatical',
#  'pity',
#  'setbolt',
#  'contradistinct',
#  'overstudied',
#  'previsive',
#  'sory',
#  'thermopolypneic',
#  'abasedness',
#  'marital',
#  'cateran',
#  'fashionmonging',
#  'weakfish',
#  'aphasic',
#  'ovation',
#  'unbroad',
# ...
